# %% [markdown]
# # Understanding Data
#
# Data Understanding in Pandas is the first and most important step in Exploratory Data Analysis (EDA).
# It helps you quickly inspect, summarize, and get insights about your dataset
# before applying any transformations or models.

# %% [markdown]
# ### Load data

# %%
import pandas as pd

# %%
df = pd.read_csv('India_Ecommerce_Unclean_Dataset.csv')
df
# Out:
#           Order_ID   Order_Date Delivery_Date  Customer_Name  \
# 0      ORD00000001   28/09/2023    07/10/2023  Rohan Agarwal
# 1      ORD00000002   2023-12-11    2023-12-12   suresh Kumar
# 2      ORD00000003   2021-10-24    2021-11-04    Sunita Nair
# 3      ORD00000004   2024-03-31    2024-04-06      Pooja Das
# 4      ORD00000005   07-01-2022    07-11-2022      Kavya Sen
# ...            ...          ...           ...            ...
# 99995  ORD00099996          NaN           NaN   Pooja Chopra
# 99996  ORD00036659   2022-05-21    2022-05-27      meena Rao
# 99997  ORD00099998  03-Oct-2023   14-Oct-2023    Rahul Patel
# 99998  ORD00099999   2023-10-25    2023-11-05    POOJA Gupta
# 99999  ORD00100000   01-25-2024    02-06-2024    Kavya Reddy
#
#                       Customer_Email  Customer_Phone Customer_City  \
# 0       rohan.agarwal769@yahoo.co.in    9.186701e+11        Chenai
# 1         suresh.kumar998yahoo.co.in    9.193598e+11          PUNE
# ...

# %% [markdown]
# ### view the data

# %% [markdown]
# ##### first and last rows

# %%
df.head()
# Out:
#       Order_ID  Order_Date Delivery_Date  Customer_Name  \
# 0  ORD00000001  28/09/2023    07/10/2023  Rohan Agarwal
# 1  ORD00000002  2023-12-11    2023-12-12   suresh Kumar
# 2  ORD00000003  2021-10-24    2021-11-04    Sunita Nair
# 3  ORD00000004  2024-03-31    2024-04-06      Pooja Das
# 4  ORD00000005  07-01-2022    07-11-2022      Kavya Sen
#
#                  Customer_Email  Customer_Phone Customer_City  Customer_State  \
# 0  rohan.agarwal769@yahoo.co.in    9.186701e+11        Chenai              KA
# 1    suresh.kumar998yahoo.co.in    9.193598e+11          PUNE     Maharashtra
# 2    sunita.nair877@yahoo.co.in    9.173318e+11        Indore           Bihar
# 3         pooja.das184gmail.com    9.171830e+11       Kolkata  Andhra Pradesh
# 4      kavya.sen379@hotmail.com    9.189122e+11    Ahemadabad             NaN
#
#    Customer_Pincode      Region  ... Unit_Price_INR Discount_Percent  \
# 0          684090.0         NaN  ...      119742.81            26.31
# ...

# %%
df.tail()
# Out:
#           Order_ID   Order_Date Delivery_Date Customer_Name  \
# 99995  ORD00099996          NaN           NaN  Pooja Chopra
# 99996  ORD00036659   2022-05-21    2022-05-27     meena Rao
# 99997  ORD00099998  03-Oct-2023   14-Oct-2023   Rahul Patel
# 99998  ORD00099999   2023-10-25    2023-11-05   POOJA Gupta
# 99999  ORD00100000   01-25-2024    02-06-2024   Kavya Reddy
#
#                       Customer_Email  Customer_Phone Customer_City  \
# 99995      pooja.chopra868@gmail.com    9.180279e+11        Mumbai
# 99996       meena.rao409@hotmail.com    9.168083e+11          PUNE
# 99997  rahul.patel827@rediffmail.com    9.195276e+11           NaN
# 99998     pooja.gupta101@hotmail.com    9.171351e+11         DELHI
# 99999     kavya.reddy225@outlook.com    9.190548e+11          PUNE
#
#       Customer_State  Customer_Pincode     Region  ... Unit_Price_INR  \
# 99995             TN          792197.0      SOUTH  ...       32914.31
# ...

# %% [markdown]
# ##### random sample

# %%
df.sample(8)
# Out:
#           Order_ID   Order_Date Delivery_Date  Customer_Name  \
# 24748  ORD00024749   2022-11-29    2022-12-13    Deepa Gupta
# 39531  ORD00039532   2023-09-21    2023-09-23    Meena Verma
# 30129  ORD00030130   2020-09-12    2020-09-19     Arun Kumar
# 49297  ORD00049298   2023-02-15    2023-02-22  Rohan Agarwal
# 29264  ORD00029265   2020-01-13    2020-01-23     Sunita Rao
# 40989  ORD00040990  21-Sep-2022   26-Sep-2022   Deepa Pillai
# 58731  ORD00058732   2021-12-12    2021-12-13    Divya Mehta
# 311    ORD00000312   2023/10/28    2023/11/05    Kavya Kumar
#
#                       Customer_Email  Customer_Phone Customer_City  \
# 24748     deepa.gupta176@hotmail.com    9.185904e+11       Lucknow
# 39531  meena.verma547@rediffmail.com    9.189685e+11     Bangalore
# 30129      arun.kumar679@outlook.com    9.167317e+11        Bhopal
# 49297   rohan.agarwal904@outlook.com    9.165184e+11    Ahemadabad
# 29264      sunita.rao686@outlook.com    9.197306e+11         Delhi
# ...

# %% [markdown]
# ### Check shape & structure

# %% [markdown]
# ##### shape (rows, columns)

# %%
df.shape
# Out:
# (100000, 25)

# %% [markdown]
# ##### columns name

# %%
df.columns
# Out:
# Index(['Order_ID', 'Order_Date', 'Delivery_Date', 'Customer_Name',
#        'Customer_Email', 'Customer_Phone', 'Customer_City', 'Customer_State',
#        'Customer_Pincode', 'Region', 'Category', 'Sub_Category',
#        'Product_Name', 'Product_SKU', 'Quantity', 'Unit_Price_INR',
#        'Discount_Percent', 'Tax_Percent', 'Gross_Amount_INR', 'Net_Amount_INR',
#        'Payment_Method', 'Payment_Status', 'Shipping_Method',
#        'Customer_Rating', 'Return_Status'],
#       dtype='object')

# %% [markdown]
# ##### data types

# %%
df.dtypes
# Out:
# Order_ID             object
# Order_Date           object
# Delivery_Date        object
# Customer_Name        object
# Customer_Email       object
# Customer_Phone      float64
# Customer_City        object
# Customer_State       object
# Customer_Pincode    float64
# Region               object
# Category             object
# Sub_Category         object
# Product_Name         object
# Product_SKU          object
# Quantity              int64
# Unit_Price_INR       object
# Discount_Percent    float64
# Tax_Percent         float64
# Gross_Amount_INR    float64
# Net_Amount_INR      float64
# Payment_Method       object
# Payment_Status       object
# Shipping_Method      object
# Customer_Rating     float64
# Return_Status        object
# dtype: object

# %% [markdown]
# ### Dataset Summary Info
#
# **Gives:**
#
# Total rows
#
# Column names
#
# Data types
#
# Non-null values
#
# **Help identify:**
#
# Missing values count
#
# wrong data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 25 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order_ID          99500 non-null   object
#  1   Order_Date        98990 non-null   object
#  2   Delivery_Date     97031 non-null   object
#  3   Customer_Name     99014 non-null   object
#  4   Customer_Email    99018 non-null   object
#  5   Customer_Phone    98996 non-null   float64
#  6   Customer_City     93215 non-null   object
#  7   Customer_State    88108 non-null   object
#  8   Customer_Pincode  99035 non-null   float64
#  9   Region            81744 non-null   object
#  10  Category          93659 non-null   object
#  11  Sub_Category      98995 non-null   object
#  12  Product_Name      97992 non-null   object
#  13  Product_SKU       100000 non-null  object
#  14  Quantity          100000 non-null  int64
#  15  Unit_Price_INR    99500 non-null   object
# ...

# %% [markdown]
# ### Statistical summary

# %% [markdown]
# ##### numerical columns

# %%
df.describe()
# Out:
#        Customer_Phone  Customer_Pincode       Quantity  Discount_Percent  \
# count    9.899600e+04      99035.000000  100000.000000      98926.000000
# mean     8.993317e+11     527900.944262       6.189760         31.663346
# std      1.295726e+11     277762.101224      22.116066         25.363916
# min      1.030000e+02        103.000000      -9.000000       -196.870000
# 25%      9.169359e+11     297091.500000       3.000000         14.720000
# 50%      9.179565e+11     532496.000000       5.000000         30.250000
# 75%      9.189785e+11     766195.000000       7.000000         45.790000
# max      9.200000e+11     999993.000000     499.000000        199.850000
#
#         Tax_Percent  Gross_Amount_INR  Net_Amount_INR  Customer_Rating
# count  98027.000000      1.000000e+05    9.704500e+04     98006.000000
# mean      12.631714      4.794456e+05    3.718308e+05         3.035506
# std        9.839965      1.941093e+06    1.608757e+06         1.488470
# ...

# %% [markdown]
# ##### categorical columns

# %%
df.describe(include = 'O')
# Out:
#            Order_ID  Order_Date Delivery_Date Customer_Name  \
# count         99500       98990         97031         99014
# unique        96590        7819          7901          1200
# top     ORD00058265  2021-12-23    2022-09-09   Priya Joshi
# freq              4          70            69           271
#
#                      Customer_Email Customer_City Customer_State Region  \
# count                         99018         93215          88108  81744
# unique                        96745            28             22      9
# top     rahul.sharma216@hotmail.com        Kanpur             WB  South
# freq                              3          3432           4071   9236
#
#            Category    Sub_Category               Product_Name Product_SKU  \
# count         93659           98995                      97992      100000
# unique           15              50                      39860       60513
# ...

# %% [markdown]
# ##### all columns

# %%
df.describe(include = 'all')
# Out:
#            Order_ID  Order_Date Delivery_Date Customer_Name  \
# count         99500       98990         97031         99014
# unique        96590        7819          7901          1200
# top     ORD00058265  2021-12-23    2022-09-09   Priya Joshi
# freq              4          70            69           271
# mean            NaN         NaN           NaN           NaN
# std             NaN         NaN           NaN           NaN
# min             NaN         NaN           NaN           NaN
# 25%             NaN         NaN           NaN           NaN
# 50%             NaN         NaN           NaN           NaN
# 75%             NaN         NaN           NaN           NaN
# max             NaN         NaN           NaN           NaN
#
#                      Customer_Email  Customer_Phone Customer_City  \
# count                         99018    9.899600e+04         93215
# unique                        96745             NaN            28
# ...

# %% [markdown]
# ### Row Index

# %%
df.index
# Out:
# RangeIndex(start=0, stop=100000, step=1)

# %% [markdown]
# ### Missing Values Analysis

# %%
df.isnull()
# Out:
#        Order_ID  Order_Date  Delivery_Date  Customer_Name  Customer_Email  \
# 0         False       False          False          False           False
# 1         False       False          False          False           False
# 2         False       False          False          False           False
# 3         False       False          False          False           False
# 4         False       False          False          False           False
# ...         ...         ...            ...            ...             ...
# 99995     False        True           True          False           False
# 99996     False       False          False          False           False
# 99997     False       False          False          False           False
# 99998     False       False          False          False           False
# 99999     False       False          False          False           False
#
#        Customer_Phone  Customer_City  Customer_State  Customer_Pincode  \
# ...

# %%
df.isnull().sum()
# Out:
# Order_ID              500
# Order_Date           1010
# Delivery_Date        2969
# Customer_Name         986
# Customer_Email        982
# Customer_Phone       1004
# Customer_City        6785
# Customer_State      11892
# Customer_Pincode      965
# Region              18256
# Category             6341
# Sub_Category         1005
# Product_Name         2008
# Product_SKU             0
# Quantity                0
# Unit_Price_INR        500
# Discount_Percent     1074
# Tax_Percent          1973
# Gross_Amount_INR        0
# Net_Amount_INR       2955
# Payment_Method      13220
# Payment_Status      17953
# Shipping_Method     22421
# Customer_Rating      1994
# Return_Status        9372
# dtype: int64

# %% [markdown]
# ##### percentage of missing values

# %%
(df.isnull().sum() / len(df)) * 100
# Out:
# Order_ID             0.500
# Order_Date           1.010
# Delivery_Date        2.969
# Customer_Name        0.986
# Customer_Email       0.982
# Customer_Phone       1.004
# Customer_City        6.785
# Customer_State      11.892
# Customer_Pincode     0.965
# Region              18.256
# Category             6.341
# Sub_Category         1.005
# Product_Name         2.008
# Product_SKU          0.000
# Quantity             0.000
# Unit_Price_INR       0.500
# Discount_Percent     1.074
# Tax_Percent          1.973
# Gross_Amount_INR     0.000
# Net_Amount_INR       2.955
# Payment_Method      13.220
# Payment_Status      17.953
# Shipping_Method     22.421
# Customer_Rating      1.994
# Return_Status        9.372
# dtype: float64

# %% [markdown]
# ### Duplication Data

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 99995    False
# 99996    False
# 99997    False
# 99998    False
# 99999    False
# Length: 100000, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Unique Values

# %%
df.nunique()
# Out:
# Order_ID            96590
# Order_Date           7819
# Delivery_Date        7901
# Customer_Name        1200
# Customer_Email      96745
# Customer_Phone      98806
# Customer_City          28
# Customer_State         22
# Customer_Pincode    93173
# Region                  9
# Category               15
# Sub_Category           50
# Product_Name        39860
# Product_SKU         60513
# Quantity              298
# Unit_Price_INR      99205
# Discount_Percent     8745
# Tax_Percent             5
# Gross_Amount_INR    99373
# Net_Amount_INR      96472
# Payment_Method         13
# Payment_Status          9
# Shipping_Method         7
# Customer_Rating       139
# Return_Status          10
# dtype: int64

# %% [markdown]
# ##### unique values in a specific column

# %%
df['Region'].unique()
# Out:
# array([nan, 'East India', 'north', 'SOUTH', 'East', 'Central',
#        'Northeast', 'North', 'West', 'South'], dtype=object)

# %%
df['Tax_Percent'].unique()
# Out:
# array([ 5., 12.,  0., 28., 18., nan])

# %% [markdown]
# ### Value Counts (Categorical Understanding)

# %%
df['Shipping_Method'].value_counts()
# Out:
# Shipping_Method
# Express     11171
# Same Day    11128
# Next Day    11122
# Economy     11106
# standard    11060
# EXPRESS     11026
# Standard    10966
# Name: count, dtype: int64

# %%
df['Customer_City'].value_counts()
# Out:
# Customer_City
# Kanpur           3432
# Ahemadabad       3390
# Nagpur           3386
# kolkata          3380
# Vadodara         3374
# Visakhapatnam    3370
# Lucknow          3369
# Ghaziabad        3366
# Thane            3364
# Chenai           3360
# PUNE             3357
# Mumbai           3340
# Hyderabad        3338
# Indore           3332
# Kolkata          3330
# Jaipur           3329
# Patna            3326
# Bangalore        3321
# Bangalroe        3309
# Delhi            3299
# Chennai          3296
# Hydrabad         3296
# Bhopal           3294
# Ahmedabad        3280
# mumbai           3276
# Surat            3250
# DELHI            3240
# Pune             3211
# Name: count, dtype: int64

# %%
df['Category'].value_counts()
# Out:
# Category
# Electronics               6432
# BOOKS                     6372
# Home&Kitchen              6362
# Sports                    6347
# Home & Kitchen            6319
# Beauty                    6281
# Health                    6259
# Automotive                6216
# FASHION                   6212
# Grocery                   6181
# Books                     6179
# beauty & personal care    6153
# Toys                      6131
# Fashion                   6108
# electronics               6107
# Name: count, dtype: int64

# %% [markdown]
# ## Check Column Types for Analysis

# %% [markdown]
# ##### Separate numerical & categorical

# %%
num_cols = df.select_dtypes(include=['int64','float64'])
cat_cols = df.select_dtypes(include=['object'])

# %%
num_cols
# Out:
#        Customer_Phone  Customer_Pincode  Quantity  Discount_Percent  \
# 0        9.186701e+11          684090.0         1             26.31
# 1        9.193598e+11          186238.0         7              4.39
# 2        9.173318e+11            3803.0         4              9.26
# 3        9.171830e+11          739883.0         9             17.80
# 4        9.189122e+11            5454.0         4             45.25
# ...               ...               ...       ...               ...
# 99995    9.180279e+11          792197.0         2             56.74
# 99996    9.168083e+11          614404.0         7             31.30
# 99997    9.195276e+11          250996.0         9             22.06
# 99998    9.171351e+11          990079.0        -1             21.12
# 99999    9.190548e+11          343131.0         6             57.04
#
#        Tax_Percent  Gross_Amount_INR  Net_Amount_INR  Customer_Rating
# 0              5.0         119742.81        92650.40              4.4
# ...

# %%
cat_cols
# Out:
#           Order_ID   Order_Date Delivery_Date  Customer_Name  \
# 0      ORD00000001   28/09/2023    07/10/2023  Rohan Agarwal
# 1      ORD00000002   2023-12-11    2023-12-12   suresh Kumar
# 2      ORD00000003   2021-10-24    2021-11-04    Sunita Nair
# 3      ORD00000004   2024-03-31    2024-04-06      Pooja Das
# 4      ORD00000005   07-01-2022    07-11-2022      Kavya Sen
# ...            ...          ...           ...            ...
# 99995  ORD00099996          NaN           NaN   Pooja Chopra
# 99996  ORD00036659   2022-05-21    2022-05-27      meena Rao
# 99997  ORD00099998  03-Oct-2023   14-Oct-2023    Rahul Patel
# 99998  ORD00099999   2023-10-25    2023-11-05    POOJA Gupta
# 99999  ORD00100000   01-25-2024    02-06-2024    Kavya Reddy
#
#                       Customer_Email Customer_City  Customer_State  \
# 0       rohan.agarwal769@yahoo.co.in        Chenai              KA
# 1         suresh.kumar998yahoo.co.in          PUNE     Maharashtra
# ...
